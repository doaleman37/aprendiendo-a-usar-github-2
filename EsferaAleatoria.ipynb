# %%
# %pylab inline
from mpl_toolkits.mplot3d import Axes3D
# Out:
#   File "<ipython-input-4-a943c9b4a24f>", line 4
#     ax=Axes3D(fig)
#      ^
# SyntaxError: invalid syntax

# %%
# %pylab inline
from mpl_toolkits.mplot3d import Axes3D
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
fig = figure(figsize(9.5,9.5))
ax = Axes3D(fig)
c=random.random(500)
r=c**(1.0/3.0)
t=random.random(500)
th=2.0*pi*t
k=random.random(500)
kh=arccos((2.0*k)-1.0)
x=sin(kh)*cos(th)*r
y=sin(kh)*sin(th)*r
z=r*cos(kh)
ax.scatter(x,y,z)
